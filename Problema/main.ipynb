# %%
archi = open("datos.txt")
lineas = archi.readlines()

print(lineas[-1])
for lin in lineas:
    linSep = lin.split(sep="','")
    for i in linSep:
        if(len(i)>500 and i[0] == "\t"):
            i = i[:len(i)-50]
    lin = "','".join(linSep)
    print(lin)
archi2 = open("salidas.txt", "w")
archi2.writelines(lineas)
# Out:
# 	(2917,'ENSG00000132485','2010-11-24',NULL,'ZRANB2','zinc finger, RAN-binding domain containing 2 [Source:HGNC Symbol;Acc:13058]','Homo sapiens',9606,'Znf_RanBP2x2',0,NULL,NULL,NULL,'2K1P; 3G9Y','O95218');
# INSERT INTO proteins (id,annotID,createDate,updateDate,geneName,geneDesc,species,taxID,domains,flag,flagNote,aliases,GSTpapers,PDBIDs,UniProtIDs)
#
# VALUES
#
# 	(1226,'ENSG00000003756','2010-03-18','2010-04-24','RBM5','RNA binding motif protein 5 [Source:HGNC Symbol;Acc:9902]','Homo sapiens',9606,'RRMx2; Znf_C2H2x1',NULL,NULL,'LUCA15; H37',NULL,NULL,'P52756'),
#
# 	(1227,'ENSG00000004139','2010-03-18','2010-04-24','SARM1','sterile alpha and TIR motif containing 1 [Source:HGNC Symbol;Acc:17074]','Homo sapiens',9606,'SAMx1',1,'No evidence of RNA binding','SARM; SAMD2; KIAA0524',NULL,NULL,NULL),
#
# ...
